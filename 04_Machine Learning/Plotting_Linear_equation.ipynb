# %%
import matplotlib.pyplot as plt

# %%
x = [0, 1, 2, 3, 4, 5]
y = []

for i in x:
    y.append(2 * i + 3)
    

plt.plot(x)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear Equation")
plt.show()
