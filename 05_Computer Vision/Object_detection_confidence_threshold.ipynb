# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Ground Truth & Model Output

# %%
ground_truths = [
    {
        "image_id": "image_1",
        "boxes": np.array([
            [10, 10, 50, 50],
            [60, 60, 100, 100]
        ]),
        "labels": np.array([1, 2])
    },
    {
        "image_id": "image_2",
        "boxes": np.array([
            [15, 15, 55, 55]
        ]),
        "labels": np.array([1])
    },
    {
        "image_id": "image_3",
        "boxes": np.array([
            [30, 30, 70, 70]
        ]),
        "labels": np.array([2])
    }
]

predictions = [
    {
        "image_id": "image_1",
        "boxes": np.array([
            [11, 11, 49, 49],
            [62, 62, 98, 98],
            [0, 0, 20, 20],
            [12, 12, 48, 48]
        ]),
        "labels": np.array([1, 2, 1, 1]),
        "scores": np.array([0.95, 0.72, 0.65, 0.55])
    },
    {
        "image_id": "image_2",
        "boxes": np.array([
            [16, 16, 54, 54],
            [70, 70, 100, 100]
        ]),
        "labels": np.array([1, 2]),
        "scores": np.array([0.60, 0.40])
    },
    {
        "image_id": "image_3",
        "boxes": np.array([
            [31, 31, 69, 69],
            [0, 0, 15, 15]
        ]),
        "labels": np.array([2, 1]),
        "scores": np.array([0.48, 0.35])
    }
]

print("Ground-truth images:", len(ground_truths))
print("Prediction images:", len(predictions))
# Out:
# Ground-truth images: 3
# Prediction images: 3

# %% [markdown]
# #### IoU Calculation

# %%
def calculate_iou(box1, box2):
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])

    intersection_width = max(0, x2 - x1)
    intersection_height = max(0, y2 - y1)
    intersection_area = intersection_width * intersection_height

    box1_area = max(0, box1[2] - box1[0]) * max(
        0, box1[3] - box1[1]
    )
    box2_area = max(0, box2[2] - box2[0]) * max(
        0, box2[3] - box2[1]
    )

    union_area = box1_area + box2_area - intersection_area
    if union_area == 0:
        return 0.0

    return intersection_area / union_area

# %% [markdown]
# #### Threshold Evaluation Function

# %%
def evaluate_threshold(
    predictions,
    ground_truths,
    confidence_threshold,
    iou_threshold=0.50
):
    prediction_map = {item["image_id"]: item for item in predictions}
    ground_truth_map = {
        item["image_id"]: item for item in ground_truths
    }

    image_ids = set(prediction_map) | set(ground_truth_map)
    true_positive = 0
    false_positive = 0
    false_negative = 0

    for image_id in image_ids:
        prediction = prediction_map.get(
            image_id,
            {
                "boxes": np.empty((0, 4)),
                "labels": np.array([]),
                "scores": np.array([])
            }
        )

        ground_truth = ground_truth_map.get(
            image_id,
            {
                "boxes": np.empty((0, 4)),
                "labels": np.array([])
            }
        )

        prediction_order = np.argsort(-prediction["scores"])
        matched_ground_truths = set()
        
        for prediction_index in prediction_order:
            score = prediction["scores"][prediction_index]
            if score < confidence_threshold:
                continue

            predicted_box = prediction["boxes"][prediction_index]
            predicted_label = prediction["labels"][prediction_index]

            best_iou = 0.0
            best_ground_truth_index = -1

            for ground_truth_index, ground_truth_box in enumerate(
                ground_truth["boxes"]
            ):
                if ground_truth_index in matched_ground_truths:
                    continue

                ground_truth_label = ground_truth["labels"][
                    ground_truth_index
                ]

                if predicted_label != ground_truth_label:
                    continue

                current_iou = calculate_iou(
                    predicted_box,
                    ground_truth_box
                )

                if current_iou > best_iou:
                    best_iou = current_iou
                    best_ground_truth_index = ground_truth_index

            if (
                best_iou >= iou_threshold
                and best_ground_truth_index != -1
            ):
                true_positive += 1
                matched_ground_truths.add(
                    best_ground_truth_index
                )
            else:
                false_positive += 1

        false_negative += (
            len(ground_truth["boxes"])
            - len(matched_ground_truths)
        )

    precision = true_positive / max(
        true_positive + false_positive, 1
    )

    recall = true_positive / max(true_positive + false_negative, 1)

    f1_score = (
        2 * precision * recall / max(precision + recall, 1e-12)
    )

    return {
        "threshold": confidence_threshold,
        "TP": true_positive,
        "FP": false_positive,
        "FN": false_negative,
        "precision": precision,
        "recall": recall,
        "f1_score": f1_score
    }

# %%
thresholds = np.round(np.arange(0.10, 0.96, 0.05),2)

results = [
    evaluate_threshold(
        predictions,
        ground_truths,
        confidence_threshold=threshold,
        iou_threshold=0.50
    )
    for threshold in thresholds
]

results_df = pd.DataFrame(results)
display(
    results_df.round(3)
)
# Out:
#     threshold  TP  FP  FN  precision  recall  f1_score
# 0        0.10   4   4   0      0.500    1.00     0.667
# 1        0.15   4   4   0      0.500    1.00     0.667
# 2        0.20   4   4   0      0.500    1.00     0.667
# 3        0.25   4   4   0      0.500    1.00     0.667
# 4        0.30   4   4   0      0.500    1.00     0.667
# 5        0.35   4   4   0      0.500    1.00     0.667
# 6        0.40   4   3   0      0.571    1.00     0.727
# 7        0.45   4   2   0      0.667    1.00     0.800
# 8        0.50   3   2   1      0.600    0.75     0.667
# 9        0.55   3   2   1      0.600    0.75     0.667
# 10       0.60   3   1   1      0.750    0.75     0.750
# 11       0.65   2   1   2      0.667    0.50     0.571
# 12       0.70   2   0   2      1.000    0.50     0.667
# 13       0.75   1   0   3      1.000    0.25     0.400
# 14       0.80   1   0   3      1.000    0.25     0.400
# 15       0.85   1   0   3      1.000    0.25     0.400
# 16       0.90   1   0   3      1.000    0.25     0.400
# 17       0.95   1   0   3      1.000    0.25     0.400

# %% [markdown]
# #### Best Threshold

# %%
best_result = (
    results_df
    .sort_values(
        by=["f1_score", "precision"],
        ascending=False
    )
    .iloc[0]
)

best_threshold = float(best_result["threshold"])

print(f"Best confidence threshold: {best_threshold:.2f}")
print(f"Precision: {best_result['precision']:.3f}")
print(f"Recall: {best_result['recall']:.3f}")
print(f"F1-score: {best_result['f1_score']:.3f}")
# Out:
# Best confidence threshold: 0.45
# Precision: 0.667
# Recall: 1.000
# F1-score: 0.800

# %%
plt.figure(figsize=(10, 6))

plt.plot(
    results_df["threshold"],
    results_df["precision"],
    marker="o",
    label="Precision"
)

plt.plot(
    results_df["threshold"],
    results_df["recall"],
    marker="o",
    label="Recall"
)

plt.plot(
    results_df["threshold"],
    results_df["f1_score"],
    marker="o",
    linewidth=3,
    label="F1-score"
)

plt.axvline(
    best_threshold,
    color="red",
    linestyle="--",
    label=f"Best threshold = {best_threshold:.2f}"
)

plt.xlabel("Confidence Threshold")
plt.ylabel("Score")
plt.title("Confidence Threshold Tuning")
plt.ylim(0, 1.05)
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# ##### Final Prediction Filter

# %%
def filter_predictions(model_output, threshold):
    keep = model_output["scores"] >= threshold

    return {
        "image_id": model_output["image_id"],
        "boxes": model_output["boxes"][keep],
        "labels": model_output["labels"][keep],
        "scores": model_output["scores"][keep]
    }


final_predictions = [
    filter_predictions(output, best_threshold)
    for output in predictions
]

for output in final_predictions:
    print(f"\nImage: {output['image_id']}")
    print("Kept confidence scores:", output["scores"])
# Out:
# Image: image_1
# Kept confidence scores: [0.95 0.72 0.65 0.55]
#
# Image: image_2
# Kept confidence scores: [0.6]
#
# Image: image_3
# Kept confidence scores: [0.48]
